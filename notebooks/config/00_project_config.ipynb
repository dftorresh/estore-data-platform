# %%
# Azure Storage
STORAGE_ACCOUNT = "stestoredev"
CONTAINER = "lakehouse"
TENANT_ID = "c663c238-850c-4607-b6b9-68bd013846b1"

# Databricks Secret Scope
SECRET_SCOPE = "estore-dbws-secret-scope"

# Azure SQL
jdbc_hostname = "sql-estore-dev.database.windows.net"
jdbc_port = 1433
jdbc_database = "EStoreERP"
SQL_USER_SECRET = "azure-sql-erp-user"
SQL_PASS_SECRET = "azure-sql-erp-password"

BRONZE_PATH = (
    f"abfss://{CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net/bronze"
)

SILVER_PATH = (
    f"abfss://{CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net/silver"
)

GOLD_PATH = (
    f"abfss://{CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net/gold"
)

METADATA_PATH = (
    f"abfss://{CONTAINER}@{STORAGE_ACCOUNT}.dfs.core.windows.net/metadata"
)
