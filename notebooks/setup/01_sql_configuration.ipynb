# %%
# %run ./../config/00_project_config

# %%
jdbc_user = dbutils.secrets.get(SECRET_SCOPE, SQL_USER_SECRET)
jdbc_password = dbutils.secrets.get(SECRET_SCOPE, SQL_PASS_SECRET)

# Build the JDBC URL
jdbc_url = f"jdbc:sqlserver://{jdbc_hostname}:{jdbc_port};database={jdbc_database};encrypt=true;trustServerCertificate=false;hostNameInCertificate=*.database.windows.net;loginTimeout=30;"

# %%
df = (spark.read
      .format("jdbc") # Or "jdbc"
      .options(url = jdbc_url, dbtable = "dbo.Customers", user = jdbc_user, password = jdbc_password)
      .load())

df.show()
