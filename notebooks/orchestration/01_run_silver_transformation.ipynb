# %%
# %run ./../silver/01_transform_customers

# %%
# %run ./../silver/02_transform_products

# %%
# %run ./../silver/03_transform_categories

# %%
# %run ./../silver/04_transform_order_items

# %%
# %run ./../silver/05_transform_orders

# %%
# %run ./../silver/06_transform_payments

# %%
# %run ./../silver/07_transform_addresses

# %%
# %run ./../silver/08_transform_suppliers

# %%
# %run ./../silver/09_transform_warehouses

# %%
# %run ./../silver/10_transform_inventory

# %%
# %run ./../silver/11_transform_shipments
