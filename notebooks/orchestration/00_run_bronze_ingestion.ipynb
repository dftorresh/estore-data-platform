# %%
# %run ./../bronze/01_ingest_customers

# %%
# %run ./../bronze/02_ingest_addresses

# %%
# %run ./../bronze/03_ingest_products

# %%
# %run ./../bronze/04_ingest_suppliers

# %%
# %run ./../bronze/05_ingest_warehouses

# %%
# %run ./../bronze/06_ingest_inventory

# %%
# %run ./../bronze/07_ingest_categories

# %%
# %run ./../bronze/08_ingest_orders

# %%
# %run ./../bronze/09_ingest_orders_items

# %%
# %run ./../bronze/10_ingest_payments

# %%
# %run ./../bronze/11_ingest_shipments
